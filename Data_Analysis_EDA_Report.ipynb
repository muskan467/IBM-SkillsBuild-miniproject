# %% [markdown]
# <a href="https://colab.research.google.com/github/muskan467/IBM-SkillsBuild-miniproject/blob/main/Data_Analysis_EDA_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
## Reading the data in
df = pd.read_csv("covid_19_india.csv")

# take a look at the dataset
df.head()
# Out:
#    Sno        Date     Time  ... Cured Deaths Confirmed
# 0    1  2020-01-30  6:00 PM  ...     0      0         1
# 1    2  2020-01-31  6:00 PM  ...     0      0         1
# 2    3  2020-02-01  6:00 PM  ...     0      0         2
# 3    4  2020-02-02  6:00 PM  ...     0      0         3
# 4    5  2020-02-03  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16850 entries, 0 to 16849
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       16850 non-null  int64
#  1   Date                      16850 non-null  object
#  2   Time                      16850 non-null  object
#  3   State/UnionTerritory      16850 non-null  object
#  4   ConfirmedIndianNational   16850 non-null  object
#  5   ConfirmedForeignNational  16850 non-null  object
#  6   Cured                     16850 non-null  int64
#  7   Deaths                    16850 non-null  int64
#  8   Confirmed                 16850 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                 Sno         Cured         Deaths     Confirmed
# count  16850.000000  1.685000e+04   16850.000000  1.685000e+04
# mean    8425.500000  2.360353e+05    3485.222552  2.583667e+05
# std     4864.320353  5.225438e+05    9330.541749  5.672808e+05
# min        1.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     4213.250000  2.658500e+03      22.000000  3.644750e+03
# 50%     8425.500000  2.889500e+04     453.000000  3.336150e+04
# 75%    12637.750000  2.537510e+05    3071.250000  2.666530e+05
# max    16850.000000  5.872268e+06  123531.000000  6.113335e+06

# %%
state_wise = df.groupby('State/UnionTerritory')['Confirmed','Cured','Deaths'].sum().reset_index()
state_wise["Death_percentage"] = ((state_wise["Deaths"] / state_wise["Confirmed"]) * 100)
state_wise.style.background_gradient(cmap='magma')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <style  type="text/css" >
# #T_243ac058_e63c_11eb_bf0f_0242ac1c0002row0_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row0_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row0_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row2_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row5_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row5_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row5_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row6_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row6_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row6_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row6_col4,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row9_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row9_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row9_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row10_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row10_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row10_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row11_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row11_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row11_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row11_col4,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row21_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row21_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row21_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row22_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row22_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row22_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row26_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row27_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row27_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row27_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row28_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row33_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row33_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row33_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row38_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row38_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row38_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row38_col4{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row0_col4{
#             background-color:  #ae347b;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row1_col1{
#             background-color:  #7b2382;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row1_col2{
#             background-color:  #812581;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row1_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row14_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row14_col2{
#             background-color:  #1d1147;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row1_col4{
#             background-color:  #59157e;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row2_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row2_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row7_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row25_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row26_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row26_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row28_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row28_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row37_col3{
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row2_col4,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row4_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row15_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row23_col2{
#             background-color:  #1c1044;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row3_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row31_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row31_col2{
#             background-color:  #110c2f;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row3_col2{
#             background-color:  #120d31;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row3_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row13_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row13_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row16_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row16_col2{
#             background-color:  #02020d;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row3_col4,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row36_col4{
#             background-color:  #3d0f71;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row4_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row15_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row23_col1{
#             background-color:  #1a1042;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row4_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row35_col1{
#             background-color:  #050416;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row4_col4{
#             background-color:  #51127c;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row5_col4,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row39_col4{
#             background-color:  #aa337d;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row7_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row7_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row25_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row25_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row35_col3{
#             background-color:  #010106;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row7_col4,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row34_col4{
#             background-color:  #b2357b;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row8_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row8_col2,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row32_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row32_col2{
#             background-color:  #221150;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row8_col3{
#             background-color:  #100b2d;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row8_col4{
#             background-color:  #9c2e7f;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row9_col4,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row30_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row37_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row37_col2{
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row10_col4,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row36_col3{
#             background-color:  #02020b;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row12_col1{
#             background-color:  #54137d;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row12_col2{
#             background-color:  #5a167e;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row12_col3{
#             background-color:  #3f0f72;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row12_col4{
#             background-color:  #e24d66;
#             color:  #000000;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row13_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row16_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row30_col1,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row30_col2{
#             background-color:  #020109;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row13_col4{
#             background-color:  #c73d73;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row14_col3{
#             background-color:  #130d34;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row14_col4{
#             background-color:  #d6456c;
#             color:  #f1f1f1;
#         }#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row15_col3,#T_243ac058_e63c_11eb_bf0f_0242ac1c0002row32_col3{
#             background-color:  #090720;
#             color:  #f1f

# %%
px.bar(x=state_wise.nlargest(10,"Confirmed")["State/UnionTerritory"],
       y = state_wise.nlargest(10,"Confirmed")["Confirmed"],
       color_discrete_sequence=px.colors.diverging.Picnic,
       title="Top 10 states with highest number of Confirmed cases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="66baf17d-8b63-4833-8b93-583e1684a865" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("66baf17d-8b63-4833-8b93-583e1684a865")) {
#                     Plotly.newPlot(
#                         '66baf17d-8b63-4833-8b93-583e1684a865',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(0,0,255)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Karnataka", "Kerala", "Tamil Nadu", "Andhra Pradesh", "Uttar Pradesh", "Delhi", "West Bengal", "Rajasthan", "Chhattisgarh"], "xaxis": "x", "y": [908892470, 387597335, 344319045, 342829697, 324146783, 252843682, 236972842, 209822848, 128998101, 128751782], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=state_wise.nlargest(10,"Cured")["State/UnionTerritory"],
       y = state_wise.nlargest(10,"Cured")["Cured"],
       color_discrete_sequence=px.colors.sequential.Sunset,
       title="Top 10 states with highest number of Cured cases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="95876cfd-734c-4869-b0f8-c0e26bb213c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("95876cfd-734c-4869-b0f8-c0e26bb213c4")) {
#                     Plotly.newPlot(
#                         '95876cfd-734c-4869-b0f8-c0e26bb213c4',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(243, 231, 155)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Karnataka", "Tamil Nadu", "Kerala", "Andhra Pradesh", "Uttar Pradesh", "Delhi", "West Bengal", "Odisha", "Rajasthan"], "xaxis": "x", "y": [813788907, 345648926, 317067499, 311127643, 303427899, 232529439, 224062704, 195296839, 117984789, 117312772], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=state_wise.nlargest(10,"Deaths")["State/UnionTerritory"],
       y = state_wise.nlargest(10,"Deaths")["Deaths"],
       color_discrete_sequence=px.colors.diverging.curl,
       title="Top 10 states with highest number of Deaths")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e17ef7f4-6a2a-4c52-9755-01acd75ffd7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e17ef7f4-6a2a-4c52-9755-01acd75ffd7f")) {
#                     Plotly.newPlot(
#                         'e17ef7f4-6a2a-4c52-9755-01acd75ffd7f',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(20, 29, 67)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Karnataka", "Tamil Nadu", "Delhi", "Uttar Pradesh", "West Bengal", "Andhra Pradesh", "Punjab", "Gujarat", "Chhattisgarh"], "xaxis": "x", "y": [19314532, 4819018, 4731627, 4066907, 3347656, 3214840, 2475816, 2216735, 1866811, 1591126], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=state_wise.nlargest(10,"Death_percentage")["State/UnionTerritory"],
       y = state_wise.nlargest(10,"Death_percentage")["Death_percentage"],
       color_discrete_sequence=px.colors.diverging.Portland,
       title="Top 10 states with highest of Death percentage")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="11481d93-0686-4be3-9830-d6a0a3cd50b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11481d93-0686-4be3-9830-d6a0a3cd50b7")) {
#                     Plotly.newPlot(
#                         '11481d93-0686-4be3-9830-d6a0a3cd50b7',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(12,51,131)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Punjab", "Maharashtra", "Sikkim", "Uttarakhand", "Delhi", "Gujarat", "Himachal Pradesh", "Puducherry", "West Bengal", "Goa"], "xaxis": "x", "y": [2.80601089766184, 2.1250623849925834, 1.7935503876236818, 1.7691177403379106, 1.716191174345624, 1.6295826340309196, 1.6134329503567801, 1.574424063327307, 1.5321686988063379, 1.5186625353202514], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# ### Exploratory Data Analysis of StatewiseTestingDetails Dataset

# %%
covid_testing = pd.read_csv("StatewiseTestingDetails.csv")
covid_testing['Date'] = covid_testing['Date'].astype('datetime64[ns]')
covid_testing.head()
# Out:
#         Date                        State  TotalSamples Negative  Positive
# 0 2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1 2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2 2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3 2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4 2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
covid_testing.shape
# Out:
# (15113, 5)

# %%
covid_testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15113 entries, 0 to 15112
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          15113 non-null  datetime64[ns]
#  1   State         15113 non-null  object
#  2   TotalSamples  15113 non-null  float64
#  3   Negative      6657 non-null   object
#  4   Positive      5589 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 590.5+ KB

# %%
covid_testing['Negative'] = covid_testing['TotalSamples'] - covid_testing['Positive']
covid_testing = covid_testing.dropna()
covid_testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5589 entries, 0 to 14794
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5589 non-null   datetime64[ns]
#  1   State         5589 non-null   object
#  2   TotalSamples  5589 non-null   float64
#  3   Negative      5589 non-null   float64
#  4   Positive      5589 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 262.0+ KB

# %%
covid_testing_state = covid_testing.groupby('State')['TotalSamples','Negative','Positive'].max().reset_index()
covid_testing_state["Positive_percentage"] = ((covid_testing["Positive"] / covid_testing["TotalSamples"]) * 100)
covid_testing_state.style.background_gradient(cmap='gist_earth_r')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <style  type="text/css" >
# #T_a623a012_e63c_11eb_bf0f_0242ac1c0002row0_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row0_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row23_col4{
#             background-color:  #f3e1e0;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row0_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row7_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row7_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row9_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row21_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row21_col2{
#             background-color:  #fcf8f8;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row0_col4{
#             background-color:  #3a8d65;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row1_col1{
#             background-color:  #bdaa63;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row1_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row15_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row29_col3{
#             background-color:  #bfa664;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row1_col3{
#             background-color:  #d5b194;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row1_col4{
#             background-color:  #1f557b;
#             color:  #f1f1f1;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row2_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row2_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row6_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row20_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row20_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row33_col3{
#             background-color:  #fbf5f5;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row2_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row5_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row5_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row5_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row7_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row12_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row17_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row17_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row17_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row20_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row21_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row22_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row22_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row22_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row23_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row23_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row23_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row26_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row28_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row28_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row28_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row31_col4{
#             background-color:  #fdfbfb;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row2_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row14_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row14_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row19_col3{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row3_col1{
#             background-color:  #c8a779;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row3_col2{
#             background-color:  #caa87b;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row3_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row22_col4{
#             background-color:  #eed8d4;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row3_col4{
#             background-color:  #37886e;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row4_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row8_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row15_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row16_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row30_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row31_col2{
#             background-color:  #dab7a0;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row4_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row17_col4{
#             background-color:  #ddb9a5;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row4_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row25_col2{
#             background-color:  #edd5d1;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row4_col4{
#             background-color:  #c6a574;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row5_col4{
#             background-color:  #cdaa82;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row6_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row6_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row28_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row33_col4{
#             background-color:  #f1dcda;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row6_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row24_col2{
#             background-color:  #d0ad8a;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row7_col4{
#             background-color:  #d1ae8c;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row8_col2{
#             background-color:  #debba7;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row8_col3{
#             background-color:  #e3c3b6;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row8_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row34_col1{
#             background-color:  #d4b091;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row9_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row12_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row12_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row30_col4{
#             background-color:  #faf2f2;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row9_col2,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row13_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row27_col4{
#             background-color:  #f9efef;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row9_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row10_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row11_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row34_col2{
#             background-color:  #d6b196;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row10_col1{
#             background-color:  #86aa55;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row10_col2{
#             background-color:  #84a954;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row10_col3,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row34_col3{
#             background-color:  #e6c7bc;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row11_col1{
#             background-color:  #419552;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row11_col2{
#             background-color:  #429650;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row11_col3{
#             background-color:  #ceab85;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row12_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row30_col1{
#             background-color:  #d8b49b;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row13_col1,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row13_col2{
#             background-color:  #e7c9bf;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row13_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row14_col4,#T_a623a012_e63c_11eb_bf0f_0242ac1c0002row31_col1{
#             background-color:  #d9b59d;
#             color:  #000000;
#         }#T_a623a012_e63c_11eb_bf0f_0242ac1c0002ro

# %%
px.bar(x=covid_testing_state.nlargest(10,"TotalSamples")["State"],
       y = covid_testing_state.nlargest(10,"TotalSamples")["TotalSamples"],
       labels={'y':'Total Samples','x':'State'},
       color_discrete_sequence=px.colors.sequential.haline,
       title="Top 10 states with highest number of Total Samples")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bf3adbff-4d32-42c8-9d23-2e075def47d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bf3adbff-4d32-42c8-9d23-2e075def47d1")) {
#                     Plotly.newPlot(
#                         'bf3adbff-4d32-42c8-9d23-2e075def47d1',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total Samples=%{y}", "legendgroup": "", "marker": {"color": "rgb(41, 24, 107)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Jharkhand", "Kerala", "Maharashtra", "Haryana", "Gujarat", "Tamil Nadu", "Uttar Pradesh", "Andhra Pradesh", "Karnataka", "Punjab"], "xaxis": "x", "y": [10298110.0, 9659492.0, 8548036.0, 5913873.0, 4356062.0, 4062943.0, 3209587.0, 2534304.0, 2314485.0, 2167731.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=covid_testing_state.nlargest(10,"Negative")["State"],
       y = covid_testing_state.nlargest(10,"Negative")["Negative"],
       labels={'y':'Total Negative cases','x':'State'},
       color_discrete_sequence=px.colors.sequential.turbid,
       title="Top 10 states with highest number of Negative cases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f3092206-5742-4d6e-8c79-73f0678517d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f3092206-5742-4d6e-8c79-73f0678517d2")) {
#                     Plotly.newPlot(
#                         'f3092206-5742-4d6e-8c79-73f0678517d2',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total Negative cases=%{y}", "legendgroup": "", "marker": {"color": "rgb(232, 245, 171)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Jharkhand", "Kerala", "Maharashtra", "Haryana", "Gujarat", "Tamil Nadu", "Uttar Pradesh", "Andhra Pradesh", "Karnataka", "Punjab"], "xaxis": "x", "y": [9952072.0, 8726853.0, 6909075.0, 5638736.0, 4220058.0, 3695513.0, 3082865.0, 2298779.0, 2049939.0, 2043196.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=covid_testing_state.nlargest(10,"Positive")["State"],
       y = covid_testing_state.nlargest(10,"Positive")["Positive"],
       labels={'y':'Total Positive Cases','x':'State'},
       color_discrete_sequence=px.colors.sequential.solar,
       title="Top 10 states with highest number of Positive cases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="21a90c64-f1f3-4a28-be84-464195509c04" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("21a90c64-f1f3-4a28-be84-464195509c04")) {
#                     Plotly.newPlot(
#                         '21a90c64-f1f3-4a28-be84-464195509c04',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total Positive Cases=%{y}", "legendgroup": "", "marker": {"color": "rgb(51, 19, 23)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Kerala", "Tamil Nadu", "Jharkhand", "Haryana", "Karnataka", "Andhra Pradesh", "Delhi", "Gujarat", "West Bengal"], "xaxis": "x", "y": [1638961.0, 932639.0, 367430.0, 346038.0, 275137.0, 264546.0, 235525.0, 151928.0, 136004.0, 135596.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=covid_testing_state.nlargest(10,"Positive_percentage")["State"],
       y = covid_testing_state.nlargest(10,"Positive_percentage")["Positive_percentage"],
       labels={'y':'Positive Percentage','x':'State'},
       color_discrete_sequence=px.colors.sequential.Aggrnyl,
       title="Top 10 states with highest Positive percentage",
       height = 420)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="91e19de4-a117-4a5d-a7b7-0ea2166de362" class="plotly-graph-div" style="height:420px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("91e19de4-a117-4a5d-a7b7-0ea2166de362")) {
#                     Plotly.newPlot(
#                         '91e19de4-a117-4a5d-a7b7-0ea2166de362',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Positive Percentage=%{y}", "legendgroup": "", "marker": {"color": "rgb(36, 86, 104)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Arunachal Pradesh", "Andhra Pradesh", "Assam", "Andaman and Nicobar Islands", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra and Nagar Haveli and Daman and Diu", "Delhi", "Goa"], "xaxis": "x", "y": [1.1587078651685394, 1.007838745800672, 0.8790623335109218, 0.8553100498930863, 0.4942339373970346, 0.47379755922469485, 0.465970064953403, 0.46044370029300963, 0.45435770342833537, 0.4503889722942541], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 420, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %% [markdown]
# ## Vaccination Analysis

# %%
vaccination = pd.read_csv(r"covid_vaccine_statewise.csv")
vaccination.head()
# Out:
#    Updated On  State  ...  60+ years (Age)  Total Individuals Vaccinated
# 0  16/01/2021  India  ...              NaN                       48276.0
# 1  17/01/2021  India  ...              NaN                       58604.0
# 2  18/01/2021  India  ...              NaN                       99449.0
# 3  19/01/2021  India  ...              NaN                      195525.0
# 4  20/01/2021  India  ...              NaN                      251280.0
#
# [5 rows x 18 columns]

# %%
vaccination.shape
# Out:
# (6699, 18)

# %%
vaccination.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                335
# Total Sessions Conducted                336
# Total Sites                             336
# First Dose Administered                 336
# Second Dose Administered                336
# Male(Individuals Vaccinated)            336
# Female(Individuals Vaccinated)          336
# Transgender(Individuals Vaccinated)     336
# Total Covaxin Administered              336
# Total CoviShield Administered           336
# Total Sputnik V Administered           4962
# AEFI                                   2519
# 18-45 years (Age)                      2522
# 45-60 years (Age)                      2521
# 60+ years (Age)                        2521
# Total Individuals Vaccinated            336
# dtype: int64

# %%
vaccination = vaccination.drop(columns=['Total Sputnik V Administered','AEFI', '18-45 years (Age)','45-60 years (Age)','60+ years (Age)'], axis=1)

# %%
vaccination.head()
# Out:
#    Updated On  ... Total Individuals Vaccinated
# 0  16/01/2021  ...                      48276.0
# 1  17/01/2021  ...                      58604.0
# 2  18/01/2021  ...                      99449.0
# 3  19/01/2021  ...                     195525.0
# 4  20/01/2021  ...                     251280.0
#
# [5 rows x 13 columns]

# %%
male = vaccination["Male(Individuals Vaccinated)"].sum() 
female = vaccination["Female(Individuals Vaccinated)"].sum()  
trans = vaccination["Transgender(Individuals Vaccinated)"].sum()
px.pie(names=["Male Vaccinated","Female Vaccinated","Trans Gender"],values=[male,female,trans],title="Male and Female Vaccinated ratio for Covid19")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="29f55baa-83c6-4ff4-8581-1e30a4230bb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("29f55baa-83c6-4ff4-8581-1e30a4230bb9")) {
#                     Plotly.newPlot(
#                         '29f55baa-83c6-4ff4-8581-1e30a4230bb9',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "label=%{label}<br>value=%{value}", "labels": ["Male Vaccinated", "Female Vaccinated", "Trans Gender"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [18579894484.0, 16340809968.0, 5315608.0]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
Covaxin = vaccination["Total Covaxin Administered"].sum() 
Covishield = vaccination["Total CoviShield Administered"].sum()  
px.pie(names=["Covaxin Vaccinated","Covishield Vaccinated"],values=[Covaxin,Covishield],title="Covaxin and Covishield Vaccination")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a1464589-1525-4f04-b61d-6423ed65be10" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a1464589-1525-4f04-b61d-6423ed65be10")) {
#                     Plotly.newPlot(
#                         'a1464589-1525-4f04-b61d-6423ed65be10',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "label=%{label}<br>value=%{value}", "labels": ["Covaxin Vaccinated", "Covishield Vaccinated"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [4408372879.0, 36316339316.0]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
Doses = vaccination["Total Doses Administered"].sum() 
Vaccinated = vaccination["Total Individuals Vaccinated"].sum()  
px.pie(names=["Doses Administered","People Vaccinated"],values=[Doses,Vaccinated],title="Doses administered vs People Vaccinated")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d6f752ae-889b-46ae-97f3-3e21aab6a005" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d6f752ae-889b-46ae-97f3-3e21aab6a005")) {
#                     Plotly.newPlot(
#                         'd6f752ae-889b-46ae-97f3-3e21aab6a005',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "label=%{label}<br>value=%{value}", "labels": ["Doses Administered", "People Vaccinated"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [40814304071.0, 33503614338.0]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...
